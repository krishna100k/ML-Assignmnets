# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
url = "https://raw.githubusercontent.com/jayumap/Machine-Learning/main/LAB%207%20Feature%20Engineering/adult.csv"
df = pd.read_csv(url)
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
myDF = df.replace("?", np.nan)
myDF
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           NaN  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
myDF["workclass"] = myDF["workclass"].fillna("Unknown")
myDF
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18       Unknown  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
X = myDF["workclass"]
y = myDF["gender"]
X_encoded = pd.get_dummies(X)
lr = LabelEncoder()
y_encoded = lr.fit_transform(y)
# Out:
# array([1, 1, 1, 1, 0, 1, 1, 1, 0, 1])

# %%
import pandas as pd

# Sample DataFrame
data = {'Age': [25, 30, 35, 40, 50, 60, 70, 80, 90]}
bDF = pd.DataFrame(data)

# Binning using equal-width bins
bins = [20, 40, 60, 80, 100]
labels = ['20-40', '40-60', '60-80', '80-100']
bDF['Age_Bin'] = pd.cut(df['Age'], bins=bins, labels=labels)
bDF
# Out:
#    Age Age_Bin
# 0   25   20-40
# 1   30   20-40
# 2   35   20-40
# 3   40   20-40
# 4   50   40-60
# 5   60   40-60
# 6   70   60-80
# 7   80   60-80
# 8   90  80-100
